# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Teenagers

# %%
teens = pd.read_csv("data/teens.csv")
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# mean selftext len

# %%
teens.groupby(teens.flair).selftext_wc.mean()
# Out:
# flair
# advice          42.646195
# art              8.345769
# discussion      19.776006
# media            7.479805
# meme             6.406937
# other           14.749840
# rant            53.758942
# relationship    44.912611
# serious         47.199254
# social          16.184468
# Name: selftext_wc, dtype: float64

# %% [markdown]
# percent of posts with empty selftext

# %%
(teens.selftext_wc <= 1).groupby(teens.flair).mean() * 100
# Out:
# flair
# advice          49.426809
# art             87.481049
# discussion      52.013829
# media           84.138656
# meme            82.361013
# other           59.852873
# rant            46.272586
# relationship    51.443787
# serious         54.587274
# social          58.226664
# Name: selftext_wc, dtype: float64

# %%
teens.groupby(teens.flair).title_wc.mean()
# Out:
# flair
# advice           9.751314
# art             10.853138
# discussion       9.413691
# media           10.408590
# meme             7.713123
# other            9.572857
# rant            10.006866
# relationship     9.072276
# serious          9.729993
# social           9.082767
# Name: title_wc, dtype: float64

# %%
(teens.title_wc <= 1).groupby(teens.flair).mean() * 100
# Out:
# flair
# advice          0.598791
# art             0.052193
# discussion      0.579924
# media           0.163596
# meme            0.184185
# other           0.413161
# rant            0.712984
# relationship    0.510517
# serious         0.425071
# social          0.402625
# Name: title_wc, dtype: float64

# %%
teens.selftext_wc[(teens.selftext_wc > 1) & (teens.selftext_wc < 50)].hist(by=teens.flair)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd8c00fd820>,
# ...
#       dtype=object)

# %%
teens.selftext_cc[(teens.selftext_wc > 1) & (teens.selftext_cc < 700)].hist(by=teens.flair)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd8bee72fa0>,
# ...
#       dtype=object)

# %%
teens.title_wc[(teens.title_wc < 20)].hist(by=teens.flair)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd91b3eddc0>,
# ...
#       dtype=object)

# %%
teens.title_cc[(teens.title_cc < 100)].hist(by=teens.flair)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd8be7964c0>,
# ...
#       dtype=object)

# %% [markdown]
# # AmItheAsshole

# %%
aita = pd.read_csv("data/aita.csv")
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
aita.selftext_wc[(aita.selftext_wc > 1) & (aita.selftext_wc < 1000)].hist(by=aita.flair)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd8af4a7460>,
# ...
#       dtype=object)

# %%
aita.title_wc[(aita.title_wc > 0) & (aita.title_wc < 30)].hist(by=aita.flair)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd8aeb2ce20>,
# ...
#       dtype=object)

# %%
aita.selftext_cc[(aita.selftext_wc > 1) & (aita.selftext_cc < 4000)].hist(by=aita.flair) #4000 seems to be the limit
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd8ae014580>,
# ...
#       dtype=object)

# %%
aita.title_cc[(aita.title_cc < 150)].hist(by=aita.flair) #200 seems to be the limit
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd8ad7dc5b0>,
# ...
#       dtype=object)

# %%
aita.groupby(aita.flair).selftext_wc.mean()
# Out:
# flair
# asshole            252.717969
# everyone sucks     293.140497
# meta                26.400000
# no a-holes here    249.360008
# not enough info    235.014287
# not the a-hole     298.909600
# tl;dr              295.696246
# update              67.461145
# Name: selftext_wc, dtype: float64

# %%
(aita.selftext_wc <= 1).groupby(aita.flair).mean() * 100
# Out:
# flair
# asshole            22.523432
# everyone sucks     22.106509
# meta               88.110236
# no a-holes here    19.142202
# not enough info    21.170091
# not the a-hole     17.920770
# tl;dr              26.450512
# update             83.626479
# Name: selftext_wc, dtype: float64

# %%
aita.groupby(aita.flair).title_wc.mean()
# Out:
# flair
# asshole            12.178807
# everyone sucks     11.761373
# meta               13.237008
# no a-holes here    11.975990
# not enough info    11.627177
# not the a-hole     11.774297
# tl;dr              10.973549
# update             13.274384
# Name: title_wc, dtype: float64
